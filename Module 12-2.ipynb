# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('loan.csv', low_memory=False)
df1000 = df.sample(1000)
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 564612  NaN        NaN       9600         9600           9600.0   36 months
# 444773  NaN        NaN      15000        15000          15000.0   36 months
# 555141  NaN        NaN      10000        10000          10000.0   36 months
# 758784  NaN        NaN      21225        21225          21225.0   60 months
# 1017914 NaN        NaN       6500         6500           6500.0   36 months
#
#          int_rate  installment grade sub_grade       ...        \
# 564612       9.49       307.48     B        B2       ...
# 444773      12.62       502.67     C        C1       ...
# 555141      13.49       339.31     C        C2       ...
# 758784      23.13       599.93     F        F1       ...
# 1017914     12.29       216.80     C        C1       ...
#
#         hardship_payoff_balance_amount hardship_last_payment_amount  \
# 564612                             NaN                          NaN
# ...

# %% [markdown]
# ## Question 1A

# %%
sns.set(style='whitegrid')
g = sns.catplot(y='annual_inc', data=df1000, kind='bar')
g.set_ylabels('Income')
plt.show()

# %%
g = sns.catplot(y='annual_inc', kind='point',ci=98, data=df1000)
g.set_ylabels('Incomes')
plt.show()

# %%
g = sns.boxplot(y='annual_inc', data=df1000)
plt.show()

# %%
sns.distplot(df1000.annual_inc, bins=[0, 20000, 40000, 60000, 80000, 100000, 150000, 200000], kde=False)
plt.show()

# %% [markdown]
# ## Question 1B

# %%
gg = sns.jointplot(y='all_util', 
               x='dti',
               data=df1000, 
               kind='hex',
               dropna=True,
               xlim=(0,40),
               ylim=(0,100))
plt.show()

# %%
gg = sns.jointplot(y='all_util', 
               x='dti',
               data=df1000, 
               kind='kde',
               xlim=(0,40),
               ylim=(0,100))
plt.show()

# %%
g = sns.lmplot(x='dti', y='all_util',
                data=df1000, scatter_kws={'alpha':0.2}, fit_reg=False)
plt.show()

# %%
g = sns.stripplot(x='grade', y='all_util', data=df1000)
plt.show()

# %%
g = sns.stripplot(x='all_util', y='grade', data=df1000)
plt.show()

# %%
g = sns.boxplot(x="grade", y="all_util", data=df1000)

# %%
g = sns.swarmplot(x="grade", y="all_util", data=df1000)
plt.show()

# %%
g = sns.pointplot(x="grade", y="all_util", data=df1000, capsize=.2, hue='grade')
plt.show()

# %%
g = sns.barplot(x="grade", y="all_util", data=df1000)
plt.show()

# %% [markdown]
# ## Question 2

# %%
g = sns.pairplot(df1000, vars=['dti', 'all_util', 'int_rate', 'annual_inc'], hue='grade')
plt.show()
# Out:
# C:\Users\dhooker\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\Users\dhooker\AppData\Local\Continuum\anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
