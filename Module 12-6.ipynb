# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Wellcome.csv', encoding = "ISO-8859-1", low_memory=False)

# %%
df.head()
# Out:
#                    PMID/PMCID                                     Publisher  \
# 0                PMC3378987\n                                      Elsevier
# 1           PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 2           PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
# 3                         NaN                     American Chemical Society
# 4  PMID: 24015914 PMC3833349                      American Chemical Society
#
#                         Journal title  \
# 0  Academy of Nutrition and Dietetics
# 1                ACS Chemical Biology
# 2                ACS Chemical Biology
# 3                ACS Chemical Biology
# 4                ACS Chemical Biology
#
#                                        Article title  \
# 0  Parent support and parent mediated behaviours ...
# 1  A Novel Allosteric Inhibitor of the Uridine Di...
# 2  Chemical proteomic analysis reveals the drugab...
# 3  Discovery of ?2 Adrenergic Receptor Ligands Us...
# ...

# %%
b = df['Journal title'].unique()
len(b)
# Out:
# 985

# %%
# creating new column to clean journal titles
df.insert(5, 'JT1', '' )

# %%
df.head()
# Out:
#                    PMID/PMCID                                     Publisher  \
# 0                PMC3378987\n                                      Elsevier
# 1           PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 2           PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
# 3                         NaN                     American Chemical Society
# 4  PMID: 24015914 PMC3833349                      American Chemical Society
#
#                         Journal title  \
# 0  Academy of Nutrition and Dietetics
# 1                ACS Chemical Biology
# 2                ACS Chemical Biology
# 3                ACS Chemical Biology
# 4                ACS Chemical Biology
#
#                                        Article title  \
# 0  Parent support and parent mediated behaviours ...
# 1  A Novel Allosteric Inhibitor of the Uridine Di...
# 2  Chemical proteomic analysis reveals the drugab...
# 3  Discovery of ?2 Adrenergic Receptor Ligands Us...
# ...

# %%
# rename not working, why???
df.rename(columns={'Journal title': 'journal_title'})
# Out:
#                            PMID/PMCID  \
# 0                        PMC3378987\n
# 1                   PMCID: PMC3780468
# 2                   PMCID: PMC3621575
# 3                                 NaN
# 4          PMID: 24015914 PMC3833349
# 5                       : PMC3805332
# 6            PMCID:\n    PMC3656742\n
# 7                      PMCID: 3584654
# 8                            23373658
# 9            PMCID:\n    PMC3727331\n
# 10                  PMCID: PMC3565438
# 11                  PMCID: PMC3668577
# 12                  PMCID: PMC3606566
# 13                   \n    PMC3498934
# 14          PMID:22993091 PMC3447403
# 15                         PMC3087623
# 16                        PMC3808818
# 17    PMID: 23828613 (July 2013 Epub)
# 18                         PMC3374517
# 19                         PMC3549237
# 20                                NaN
# 21                         PMC3661931
# 22                            3535376
# 23                         PMC3798121
# ...

# %%
df['JT1'] = df['Journal title']

# %%
df.head()
# Out:
#                    PMID/PMCID                                     Publisher  \
# 0                PMC3378987\n                                      Elsevier
# 1           PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 2           PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
# 3                         NaN                     American Chemical Society
# 4  PMID: 24015914 PMC3833349                      American Chemical Society
#
#                         Journal title  \
# 0  Academy of Nutrition and Dietetics
# 1                ACS Chemical Biology
# 2                ACS Chemical Biology
# 3                ACS Chemical Biology
# 4                ACS Chemical Biology
#
#                                        Article title  \
# 0  Parent support and parent mediated behaviours ...
# 1  A Novel Allosteric Inhibitor of the Uridine Di...
# 2  Chemical proteomic analysis reveals the drugab...
# 3  Discovery of ?2 Adrenergic Receptor Ligands Us...
# ...

# %%
# make all titles lower case
df['JT1'] = df.JT1.str.lower()

# %%
# strip out all leading/trailing white space
df['JT1'] = df.JT1.str.strip()

# %%
df.head()
# Out:
#                    PMID/PMCID                                     Publisher  \
# 0                PMC3378987\n                                      Elsevier
# 1           PMCID: PMC3780468  ACS (Amercian Chemical Society) Publications
# 2           PMCID: PMC3621575  ACS (Amercian Chemical Society) Publications
# 3                         NaN                     American Chemical Society
# 4  PMID: 24015914 PMC3833349                      American Chemical Society
#
#                         Journal title  \
# 0  Academy of Nutrition and Dietetics
# 1                ACS Chemical Biology
# 2                ACS Chemical Biology
# 3                ACS Chemical Biology
# 4                ACS Chemical Biology
#
#                                        Article title  \
# 0  Parent support and parent mediated behaviours ...
# 1  A Novel Allosteric Inhibitor of the Uridine Di...
# 2  Chemical proteomic analysis reveals the drugab...
# 3  Discovery of ?2 Adrenergic Receptor Ligands Us...
# ...

# %%
a = df.JT1.unique()
a
# Out:
# array(['academy of nutrition and dietetics', 'acs chemical biology',
#        'acs chemical neuroscience', 'acs nano',
#        'acta crystallographica section d,  biological crystallography',
#        'acta crystallographica section d: biological crystallography',
#        'acta crystallographica section f: structural biology and crystallization communications',
#        'acta crystallographica, section d', 'acta crystallography d',
#        'acta d', 'acta dermato venereologica', 'acta diabetologica',
#        'acta f', 'acta neuropathol', 'acta neuropathologica',
#        'acta opthalmologica', 'acta physiol', 'addiction',
#        'advances in experimental medicine and biology', 'age',
#        'age and ageing', 'ageing & society', 'aging cell', 'aids',
#        'aids behav', 'aids care', 'aids journal',
#        'aids research and therapy', 'aids uk', 'alcohol and alcoholism',
#        'alimentrary pharmacology & therapeutics', 'am j bioeth',
# ...

# %%
len(a)
# Out:
# 895

# %%
df['JT1'] = df.JT1.str.replace(' and ', ' & ')

# %%
a = df.JT1.unique()

# %%
len(a)
# Out:
# 882

# %%
df.JT1 = df.JT1.str.replace('journal for', 'journal of')

# %%
a = df.JT1.unique()
len(a)
# Out:
# 879

# %%
df.JT1 = df.JT1.str.replace('antimicobial ', 'antimicrobial ')

# %%
a = df.JT1.unique()
len(a)
# Out:
# 878

# %%
df.JT1 = df.JT1.str.replace('agfents ', 'agents ')

# %%
a = df.JT1.unique()
len(a)
# Out:
# 877

# %%
df.JT1 = df.JT1.str.replace('behaviour', 'behavior')

# %%
a = df.JT1.unique()
len(a)
# Out:
# 874

# %%
df.JT1 = df.JT1.str.replace(' online', '')

# %%
a = df.JT1.unique()
len(a)
# Out:
# 869

# %%
a
# Out:
# array(['academy of nutrition & dietetics', 'acs chemical biology',
#        'acs chemical neuroscience', 'acs nano',
#        'acta crystallographica section d,  biological crystallography',
#        'acta crystallographica section d biological crystallography',
#        'acta crystallographica section f structural biology & crystallization communications',
#        'acta crystallographica, section d', 'acta crystallography d',
#        'acta d', 'acta dermato venereologica', 'acta diabetologica',
#        'acta f', 'acta neuropathol', 'acta neuropathologica',
#        'acta opthalmologica', 'acta physiol', 'addiction',
#        'advances in experimental medicine & biology', 'age',
#        'age & ageing', 'ageing & society', 'aging cell', 'aids',
#        'aids behav', 'aids care', 'aids journal',
#        'aids research & therapy', 'aids uk', 'alcohol & alcoholism',
#        'alimentrary pharmacology & therapeutics', 'am j bioeth',
# ...

# %%
df.JT1 = df.JT1.str.replace('plosone', 'plos one')

# %%
mylist = df.JT1.value_counts()
mylist[0]
# Out:
# 199

# %%
top5 = pd.DataFrame({'name': 'plos one', 'journ'})
